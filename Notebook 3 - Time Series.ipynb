# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
data = pd.read_csv('airbase_data.csv',index_col=0,parse_dates=True,na_values=[-9999])

# %%
#Data Exploration
data.head(3)
# Out:
#                      BETR801  BETN029  FR04037  FR04012
# 1998-01-01 00:00:00      NaN     16.0      NaN      NaN
# 1998-01-01 01:00:00      NaN     13.0      NaN      NaN
# 1998-01-01 02:00:00      NaN     12.0      NaN      NaN

# %%
data.tail()
# Out:
#                      BETR801  BETN029  FR04037  FR04012
# 2012-12-31 19:00:00     21.0      2.5     28.0     67.0
# 2012-12-31 20:00:00     16.5      2.0     16.0     47.0
# 2012-12-31 21:00:00     14.5      2.5     13.0     43.0
# 2012-12-31 22:00:00     16.5      3.5     14.0     42.0
# 2012-12-31 23:00:00     15.0      3.0     13.0     49.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 131265 entries, 1998-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 4 columns):
# BETR801    113252 non-null float64
# BETN029    119703 non-null float64
# FR04037    120384 non-null float64
# FR04012    119448 non-null float64
# dtypes: float64(4)
# memory usage: 5.0 MB

# %%
data.describe()
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              BETR801        BETN029        FR04037        FR04012
# count  113252.000000  119703.000000  120384.000000  119448.000000
# mean       47.049302      16.542171      40.040005      87.993261
# std        21.733629      12.446040      23.024347      41.317684
# min         1.000000       1.000000       0.000000       0.000000
# 25%              NaN            NaN            NaN            NaN
# 50%              NaN            NaN            NaN            NaN
# 75%              NaN            NaN            NaN            NaN
# max       339.000000     105.000000     256.000000     358.000000

# %%
#Data Visualization
from matplotlib import pyplot
# %matplotlib notebook
pyplot.rcParams['font.family'] = 'serif'
pyplot.rcParams['font.size'] = 14
pyplot.rcParams['axes.labelsize'] = 18
pyplot.show()

# %%
data.plot(kind = 'box', ylim = [0,250])
# Out:
# <img src="data:image/png;base64,...">

# %%
data.plot(figsize=(12,6))
# Out:
# <img src="data:image/png;base64,...">

# %%
data['BETR801'].plot(kind='hist',bins=50)
# Out:
# <img src="data:image/png;base64,...">

# %%
#latest 500 points
data[-500:].plot(figsize=(12,6))
# Out:
# <img src="data:image/png;base64,...">

# %%
#Working with time series data
data.index
# Out:
# DatetimeIndex(['1998-01-01 00:00:00', '1998-01-01 01:00:00',
#                '1998-01-01 02:00:00', '1998-01-01 03:00:00',
#                '1998-01-01 04:00:00', '1998-01-01 05:00:00',
#                '1998-01-01 06:00:00', '1998-01-01 07:00:00',
#                '1998-01-01 08:00:00', '1998-01-01 09:00:00',
#                ...
#                '2012-12-31 14:00:00', '2012-12-31 15:00:00',
#                '2012-12-31 16:00:00', '2012-12-31 17:00:00',
#                '2012-12-31 18:00:00', '2012-12-31 19:00:00',
#                '2012-12-31 20:00:00', '2012-12-31 21:00:00',
#                '2012-12-31 22:00:00', '2012-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=131265, freq=None)

# %%
#partial string indexing
data["2010-01-01 09:00":"2010-01-01 12:00"]
# Out:
#                      BETR801  BETN029  FR04037  FR04012
# 2010-01-01 09:00:00     17.0      7.0     19.0     41.0
# 2010-01-01 10:00:00     18.0      5.0     21.0     48.0
# 2010-01-01 11:00:00     17.0      4.0     23.0     63.0
# 2010-01-01 12:00:00     18.0      4.0     22.0     57.0

# %%
data['2012']
# Out:
#                      BETR801  BETN029  FR04037  FR04012
# 2012-01-01 00:00:00     21.0      1.0     17.0     56.0
# 2012-01-01 01:00:00     18.0      1.0     16.0     50.0
# 2012-01-01 02:00:00     20.0      1.0     14.0     46.0
# 1998-01-01 00:00:00      NaN     16.0      NaN      NaN
# 1998-01-01 01:00:00      NaN     13.0      NaN      NaN
# 1998-01-01 02:00:00      NaN     12.0      NaN      NaN
# 1998-01-01 03:00:00      NaN     12.0      NaN      NaN
# 1998-01-01 04:00:00      NaN     11.0      NaN      NaN
# 1998-01-01 05:00:00      NaN     12.0      NaN      NaN
# 1998-01-01 06:00:00      NaN     12.0      NaN      NaN
# 1998-01-01 07:00:00      NaN     10.0      NaN      NaN
# 1998-01-01 08:00:00      NaN      9.0      NaN      NaN
# 1998-01-01 09:00:00      NaN     10.0      NaN      NaN
# 1998-01-01 10:00:00      NaN     13.0      NaN      NaN
# 1998-01-01 11:00:00      NaN      7.0      NaN      NaN
# 1998-01-01 12:00:00      NaN      8.0      NaN      NaN
# 1998-01-01 13:00:00      NaN      6.0      NaN      NaN
# 1998-01-01 14:00:00      NaN      4.0      NaN      NaN
# 1998-01-01 15:00:00      NaN      4.0      NaN      NaN
# ...

# %%
#All data for Jan, Feb and March for all different years
data['months'] = data.index.month
data[data['months'].isin([1,2,3])]
# Out:
#                      BETR801  BETN029  FR04037  FR04012  months
# 1998-01-01 00:00:00      NaN     16.0      NaN      NaN       1
# 1998-01-01 01:00:00      NaN     13.0      NaN      NaN       1
# 1998-01-01 02:00:00      NaN     12.0      NaN      NaN       1
# 1998-01-01 03:00:00      NaN     12.0      NaN      NaN       1
# 1998-01-01 04:00:00      NaN     11.0      NaN      NaN       1
# 1998-01-01 05:00:00      NaN     12.0      NaN      NaN       1
# 1998-01-01 06:00:00      NaN     12.0      NaN      NaN       1
# 1998-01-01 07:00:00      NaN     10.0      NaN      NaN       1
# 1998-01-01 08:00:00      NaN      9.0      NaN      NaN       1
# 1998-01-01 09:00:00      NaN     10.0      NaN      NaN       1
# 1998-01-01 10:00:00      NaN     13.0      NaN      NaN       1
# 1998-01-01 11:00:00      NaN      7.0      NaN      NaN       1
# 1998-01-01 12:00:00      NaN      8.0      NaN      NaN       1
# 1998-01-01 13:00:00      NaN      6.0      NaN      NaN       1
# ...

# %%
#Selecting all day time data for all days
data.between_time('08:00','20:00')
# Out:
#                      BETR801  BETN029  FR04037  FR04012  months
# 1998-01-01 08:00:00      NaN      9.0      NaN      NaN       1
# 1998-01-01 09:00:00      NaN     10.0      NaN      NaN       1
# 1998-01-01 10:00:00      NaN     13.0      NaN      NaN       1
# 1998-01-01 11:00:00      NaN      7.0      NaN      NaN       1
# 1998-01-01 12:00:00      NaN      8.0      NaN      NaN       1
# 1998-01-01 13:00:00      NaN      6.0      NaN      NaN       1
# 1998-01-01 14:00:00      NaN      4.0      NaN      NaN       1
# 1998-01-01 15:00:00      NaN      4.0      NaN      NaN       1
# 1998-01-01 16:00:00      NaN      5.0      NaN      NaN       1
# 1998-01-01 19:00:00      NaN      8.0      NaN      NaN       1
# 1998-01-01 20:00:00      NaN      6.0      NaN      NaN       1
# 1998-01-02 08:00:00      NaN      5.0      NaN      NaN       1
# 1998-01-02 09:00:00      NaN      6.0      NaN      NaN       1
# 1998-01-02 10:00:00      NaN     11.0      NaN      NaN       1
# ...

# %%
#Resampling - change the frequency of 1hr to a daily basis
data.resample('D')
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\IPython\utils\dir2.py:65: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   canary = getattr(obj, '_ipython_canary_method_should_not_exist_', None)
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\IPython\utils\dir2.py:74: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   m = getattr(obj, name, None)
# DatetimeIndexResampler [freq=<Day>, axis=0, closed=left, label=left, convention=start, base=0]

# %%
data.resample('D',how='max').head()
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).max()
#   if __name__ == '__main__':
#             BETR801  BETN029  FR04037  FR04012  months
# 1998-01-01      NaN     16.0      NaN      NaN       1
# 1998-01-02      NaN     23.0      NaN      NaN       1
# 1998-01-03      NaN      9.0      NaN      NaN       1
# 1998-01-04      NaN      7.0      NaN      NaN       1
# 1998-01-05      NaN     35.0      NaN      NaN       1

# %%
data.resample('M')
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\IPython\utils\dir2.py:65: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   canary = getattr(obj, '_ipython_canary_method_should_not_exist_', None)
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\IPython\utils\dir2.py:74: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   m = getattr(obj, name, None)
# DatetimeIndexResampler [freq=<MonthEnd>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
data['2012'].resample('D').plot()
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   if __name__ == '__main__':
# <img src="data:image/png;base64,...">

# %%
#monthly mean and median concentration of the 'FR04037' station for the years 2009-2012 
data.loc['2009':,'FR04037'].resample('M',how='mean').plot()
data.loc['2009':,'FR04037'].resample('M',how='median').plot()
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   from ipykernel import kernelapp as app
# <img src="data:image/png;base64,...">
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).median()
#   app.launch_new_instance()

# %%
data.loc['2009':, 'FR04037'].resample('M', how=['mean', 'median']).plot()
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   if __name__ == '__main__':
# <img src="data:image/png;base64,...">

# %%
#QUESTION: plot the monthly mininum and maximum daily concentration of the 'BETR801' station 
daily = data['BETR801'].resample('D')
daily.resample('M', how=['min', 'max']).plot()
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   app.launch_new_instance()
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   app.launch_new_instance()
# <img src="data:image/png;base64,...">

# %%
#Bar plot of the mean of stations in year 2012
data['2012'].mean().plot(kind='bar')
# Out:
# <img src="data:image/png;base64,...">

# %%
#QUESTION: The evolution of the yearly averages with, and the overall mean of all stations?
data.resample('A').plot()
data.mean(axis=1).resample('A').plot(color='k', linestyle='--', linewidth=4)
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   from ipykernel import kernelapp as app
# <img src="data:image/png;base64,...">
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   app.launch_new_instance()

# %%
#Typical monthly profile for different stations
#Add a column to the dataframe to indicate the month
data['month'] = data.index.month

# %%
data.groupby('month').mean()
# Out:
#          BETR801    BETN029    FR04037    FR04012  months
# month
# 1      52.215706  19.990608  47.634409  82.472813       1
# 2      54.149298  20.732738  50.564499  83.973207       2
# 3      53.900213  19.681608  47.862715  96.272138       3
# 4      49.709600  17.547161  40.943117  95.962862       4
# 5      43.078248  15.368062  33.172575  89.523159       5
# 6      39.219850  11.995789  30.416467  91.036197       6
# 7      35.631752  11.006105  27.552373  88.314473       7
# 8      40.249923  12.187518  28.826405  79.596765       8
# 9      47.576890  14.467069  39.706019  93.000316       9
# 10     48.469089  17.126889  44.010934  86.297836      10
# 11     51.016339  18.368344  45.564683  87.173878      11
# 12     50.286726  20.372366  45.262243  81.817977      12

# %%
#Plot monthly profile for different stations
data.groupby('month').mean().plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Weekly 95 percentile of concentration in stations 'BETR801' and 'BETN029' for 2011 
df2011 = data['2011']
df2011.groupby(df2011.index.week)[['BETN029','BETR801']].quantile(0.95).plot()
# Out:
# C:\Users\NISHANTH\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
#QUESTION: Calculate the correlation between the different stations
data[['BETR801', 'BETN029', 'FR04037', 'FR04012']].corr()
# Out:
#           BETR801   BETN029   FR04037   FR04012
# BETR801  1.000000  0.476523  0.561676  0.394446
# BETN029  0.476523  1.000000  0.401864  0.186997
# FR04037  0.561676  0.401864  1.000000  0.433466
# FR04012  0.394446  0.186997  0.433466  1.000000
